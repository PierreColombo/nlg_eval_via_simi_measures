# %% [markdown]
# # Analysis Translation

# %%
import os 
import json
import math
from tqdm.notebook import tqdm
import scipy.stats as stats
import pandas as pd
import seaborn as sns
from matplotlib import rcParams
import sys
sys.path.append('../')
from bary_score import BaryScoreMetric
# figure size in inches
rcParams['figure.figsize'] = 20.7,8.27

# %%
def split_div(string_key):
    name, type_, alpha, beta, temp, tf_idf = '', '', -1, -1, -1, False
    if string_key in ['human','utt_level', 'DataCoverage', 'Fluency', 'Relevance', 'TextStructure', 'litepyramid_recall',
                          'responsiveness', 'js-2', 'mover_score', 'meteor', 'bleu','chrf',
                          'rouge_we_3_p', 'rouge_we_3_r', 'rouge_we_3_f']:
            name = string_key
            temp = 1
            type_ = 'normal'
            tf_idf = True
    elif 'new_score' in string_key:
            name = string_key
    elif 'bert' in string_key or 'rouge' in string_key:
            name = string_key
            temp = 1
            type_ = 'normal'
            tf_idf = True
    else:
            print('name',name)
            name = None
    assert name != ''
    assert type_ != ''
    assert temp != -1
    return name, type_, alpha, beta, temp, tf_idf

# %%
year = '15'
index = 1
data_type = ['cs-en', 'de-en', 'ru-en', 'fi-en', 'ro-en', 'tr-en'][index]
file_path = '{}_{}_formated.json'.format(year,data_type)
print('Loading {} {}'.format(year,data_type))
# Out:
# Loading 15 de-en

# %%
with open(file_path,'r') as file :
    all_data = json.load(file)

# %% [markdown]
# # Computing New BaryScore

# %%
metric = BaryScoreMetric(use_idfs=True)

refs,sentences = [],[]
for k,v in tqdm(all_data.items()):
    refs.append(v['references_sentences'])
    sentences.append(v['system']['wmt{}'.format(year)]['generated_sentence'])
    
a = metric.prepare_idfs(refs, sentences)

for k,v in tqdm(all_data.items()):
    ref = v['references_sentences']
    sentence = v['system']['wmt{}'.format(year)]['generated_sentence']
    scores = metric.evaluate_batch(ref, sentence)
    for score,value in scores.items():
        all_data[k]['system']['wmt{}'.format(year)]['scores']['new_score_{}'.format(score)] = value
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# HBox(children=(FloatProgress(value=0.0, max=500.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=500.0), HTML(value='')))
# BaryScore Progress: 100%|██████████| 1/1 [00:03<00:00,  3.15s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.33it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.69it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.15it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.34it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.06it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  5.34it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.76it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.85it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00, 47.28it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.16it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.17it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.91it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  5.41it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:01<00:00,  1.17s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.44it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.41it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.51it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.56it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.81it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.27s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.90s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00, 45.68it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.13it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.39it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.78s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.13it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.79s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.62it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.86it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.18it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.12it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  6.43it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.45it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.98it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.81s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.77s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.82it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  8.05it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.85s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.68it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.76s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.97it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.37it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.28it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.74it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.94it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.53it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.29it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.50it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:01<00:00,  1.74s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.90it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.52it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.38it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.76it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.76it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.79s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.79s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.78s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.91it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.44it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.95it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.83it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.90s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.65it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.93it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:01<00:00,  1.68s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.37it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.50it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.35it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00, 57.53it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  5.44it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.96s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:01<00:00,  1.37s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.56it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.82s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.21it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.18it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.68it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  5.49it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  6.31it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:03<00:00,  3.18s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.05it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  7.48it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.30it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:03<00:00,  3.23s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.19it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.20it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.12it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.45it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.26it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.96s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.70s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.47it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.98it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.13it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  7.71it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.23it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.92s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00, 60.51it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.81s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.95it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.44it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.71s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:01<00:00,  1.07s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  5.37it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.19it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.32it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.61it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.67it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.37it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.50it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  6.31it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.75s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.71s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:01<00:00,  1.22s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  5.09it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.78s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.68s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.72s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.89it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.09it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.99it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:01<00:00,  1.03s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.24it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.87it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  5.06it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.01it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.30it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  5.24it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.70s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.66it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.98s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  6.59it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.29it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.40it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.28it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.82it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.88it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.11it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:04<00:00,  4.11s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.11it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:01<00:00,  1.16s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.70it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.71it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  6.37it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.65it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  5.87it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.18it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  8.17it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.25it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.60it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.20it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.86it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  5.08it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.21it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.97it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.44it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.98it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  5.06it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00, 51.99it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  5.46it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.43it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  6.70it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.44it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.21it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.27it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  5.31it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.26it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.74s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.99it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.50it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.87it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.12it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  5.72it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.68s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.20it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.83it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.90it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.48it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.22it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  6.26it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.79s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.74s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.24it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.51it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.47it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.50it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:01<00:00,  1.01s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.81s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  9.80it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.19it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  5.81it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.14it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.35it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.68it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.75s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.69it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.95it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00, 44.67it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.71it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.93it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.69s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.39it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.76it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.57it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.70s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.87s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.53it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.79s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.73s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.39it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.83it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.97it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.12it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.79it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.63it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.96it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.85it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.72s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.57it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.52it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.48it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.64it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.40it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.94it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.27it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  7.54it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.08it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.60it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00, 30.07it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:01<00:00,  1.18s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.43it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.74s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.72it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  7.48it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.72it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.03it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.67it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.39it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.92s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.87it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.96it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  6.52it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.45it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.53it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.90it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.25it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.00it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:01<00:00,  1.19s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.42it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.44it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.75it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.83it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.72it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.36it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.21it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.94it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.11it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00, 59.40it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.98it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.17it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:03<00:00,  3.14s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.09it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.10it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.61it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.76it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.34it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.25it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.50it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.89s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.83s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.43it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.53it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.95it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.73s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.18it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:03<00:00,  3.43s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.66it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.03it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.32it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.94s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.51it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.51it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.83it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.87s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.11it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.31it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.55it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.27it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.39it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.51it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  5.52it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.05it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.05it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.58it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.94it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.08it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.79it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.45it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:01<00:00,  1.00s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:03<00:00,  3.16s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.11it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  5.07it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.56it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:03<00:00,  3.06s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.75it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.93it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.85it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.09it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.81it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.62it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.41it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.36it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.38it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.88it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  9.23it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:01<00:00,  1.20s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  9.57it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.27it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.55it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.94it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.71it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.30it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.41it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.02it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.84s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00, 50.67it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.60it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:01<00:00,  1.49s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:01<00:00,  1.04s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.35it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:03<00:00,  3.41s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.85it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.08s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.08it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.62it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  7.83it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:01<00:00,  1.51s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.79it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.09it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.03it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:03<00:00,  3.41s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.41it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.64it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.31it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:03<00:00,  3.92s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.30it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00, 26.94it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:04<00:00,  4.05s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.36it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:01<00:00,  1.51s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.83it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.14it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:04<00:00,  4.64s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.37it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.84it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.87it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.89it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.39it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:03<00:00,  3.07s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.48it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.74it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:03<00:00,  3.60s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.77it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.98it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.96it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.35it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.74it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.21it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.78it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.06it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.94it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.44it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.83it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:01<00:00,  1.05s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:03<00:00,  3.94s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.21it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.26it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.54it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.99it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:03<00:00,  3.47s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.76it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.83it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.82it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.89it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.12it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:01<00:00,  1.11s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.79it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.64it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:03<00:00,  3.76s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.96it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.26it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.59it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.58it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:04<00:00,  4.17s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.59it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.81it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.16it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.95it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.57it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.89it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.68it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.41it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.05it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.44it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.61it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.04it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.29it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.27it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.32it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:02<00:00,  2.20s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  4.90it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.18it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.52it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:01<00:00,  1.45s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:01<00:00,  1.00s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.60it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.88it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.71it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.37it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  5.15it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:03<00:00,  3.79s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.43it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.39it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  5.12it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.38it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.53it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.37it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:03<00:00,  3.14s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.69it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:03<00:00,  3.72s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:03<00:00,  3.70s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.81it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.79it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.76it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.67it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:03<00:00,  3.89s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:03<00:00,  3.73s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:03<00:00,  3.51s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:03<00:00,  3.11s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.30it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.98it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00, 39.31it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:01<00:00,  1.14s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.47it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.16it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.51it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:03<00:00,  3.64s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.81it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.95it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.29it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.37it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.77it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  3.13it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.36it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  1.10it/s]
# BaryScore Progress: 100%|██████████| 1/1 [00:01<00:00,  1.19s/it]
# BaryScore Progress: 100%|██████████| 1/1 [00:00<00:00,  2.48it/s]
# BaryScore Progress:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # Reproducing Correlation Computation Instance Level Correlation

# %%
final_correlations_spearman_lit = {}
final_correlations_pearson_lit = {}
final_correlations_kendall_lit = {}
ids = list(all_data.keys())[10]
sys = list(all_data[ids]['system'].keys())[0]
for metric_name,_ in tqdm(all_data[ids]['system'][sys]['scores'].items()):
        print(metric_name)
        predicted = []
        utt_golden_scores = []
        for key_data,value_data in all_data.items():
                for key_system, value_system in value_data['system'].items():
                    try :
                        predicted.append(sum(sum(value_system['scores'][metric_name],[]))/len(sum(value_system['scores'][metric_name],[])))
                    except :
                        try :
                            predicted.append(sum(value_system['scores'][metric_name]))
                        except :
                            predicted.append(value_system['scores'][metric_name])
                    utt_golden_scores.append(value_system['scores']['human'])
        predicted_score = [0 if math.isnan(x) else x for x in predicted]
        predicted_score = [0 if math.isinf(x) else x for x in predicted_score]
        predicted_score = [0 if math.isinf(-x) else x for x in predicted_score]
        if len(predicted_score) > 0 and len(utt_golden_scores) > 0:
                final_correlations_spearman_lit[metric_name] =  abs(stats.spearmanr(predicted_score, utt_golden_scores)[0])
                final_correlations_pearson_lit[metric_name] = abs(stats.pearsonr(predicted_score, utt_golden_scores)[0])
                final_correlations_kendall_lit[metric_name] = abs(stats.kendalltau(predicted_score, utt_golden_scores)[0])

# %%
names, types,alphas,betas,temps,tf_idfs,pearson_lit,spearman_lit,kendall_lit = [],[],[],[],[],[],[],[],[]
for k,value in tqdm(final_correlations_spearman_lit.items()):
    print(k)
    if 'meteor' or 'chrf' in k :
            name= k 
            tf_idf,temp,alpha,beta,type_ = 1,1,1,1,1
    else :
            if k[0] in ['2','3','4']:
                k_ = k[2:]
                add = True
            else :
                k_ = k
            name, type_, alpha, beta, temp, tf_idf = split_div(k_)
            if add :
                name += k[0]
    names.append(name)
    tf_idfs.append(tf_idf)
    temps.append(temp)
    alphas.append(alpha)
    betas.append(beta)
    types.append(type_)
    kendall_lit.append(final_correlations_kendall_lit[k])
    
    pearson_lit.append(final_correlations_pearson_lit[k])
    spearman_lit.append(final_correlations_spearman_lit[k])


df_dict = {'names': names, 'types' : types,'betas':betas,'alphas':alphas,
           'temps' : temps,'pearson' : pearson_lit, 'kendall': kendall_lit,
           'spearman':spearman_lit}
df = pd.DataFrame(df_dict)
df.to_csv('translation_baryscore_{}_{}.csv'.format(data_type,year))

# %% [markdown]
# # Reproducing Correlation Scores

# %%
summ_level = pd.read_csv('translation_baryscore_{}_{}.csv'.format(data_type,year))

# %%
summ_level.sort_values('pearson',ascending =False).head(60)
